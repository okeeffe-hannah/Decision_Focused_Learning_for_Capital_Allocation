# %% [markdown]
# # Build quarterly macro panel
#
# This notebook aggregates, aligns, transforms, and exports all data for modelling.

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import plotting_config  
import numpy as np
import pandas as pd
import yaml

CONFIG_PATH = Path('../data/raw/fred/fred_series_config.yaml')
FRED_RAW_DIR = Path("../data/raw/fred")
EBP_PATH = Path('../data/raw/ebp/ebp.csv')
OUTPUT_PATH = Path('../data/processed/macro_panel_quarterly.csv')

# %%
with CONFIG_PATH.open("r", encoding="utf-8") as file:
    SERIES_CONFIG = yaml.safe_load(file)["series"]

config = pd.DataFrame(SERIES_CONFIG)
config
# Out:
#                                name          fred_id  \
# 0                   real_gdp_growth  A191RL1Q225SBEA
# 1                 unemployment_rate           UNRATE
# 2             industrial_production           INDPRO
# 3   real_disposable_personal_income          DSPIC96
# 4                               cpi         CPIAUCSL
# 5                 house_price_index          USSTHPI
# 6                federal_funds_rate         FEDFUNDS
# 7            treasury_10y_2y_spread           T10Y2Y
# 8                               vix           VIXCLS
# 9             corporate_bond_spread           BAA10Y
# 10       senior_loan_officer_survey         DRTSCILM
# 11                  charge_off_rate        CORBLACBS
#
#                             category native_frequency quarterly_aggregation  \
# 0                      real_activity        quarterly                   NaN
# 1                      real_activity          monthly               average
# 2                      real_activity          monthly               average
# 3                      real_activity          monthly               average
# 4                             prices          monthly               average
# 5               asset_prices_housing        quarterly                   NaN
# 6            monetary_interest_rates          monthly               average
# 7            monetary_interest_rates            daily               average
# 8   financial_conditions_credit_risk            daily               average
# 9   financial_conditions_credit_risk            daily               average
# 10  financial_conditions_credit_risk        quarterly                   NaN
# 11  financial_conditions_credit_risk        quarterly                   NaN
#
#    transformation
# 0           level
# 1           level
# 2        log_diff
# 3        log_diff
# 4        log_diff
# 5        log_diff
# 6           level
# 7           level
# 8           level
# 9           level
# 10          level
# 11          level

# %% [markdown]
# ## Helper Functions

# %%
def validate_raw_dates(df: pd.DataFrame, value_col: str, label: str) -> None:
    """Check raw files before any quarterly modelling transformations."""
    if "DATE" not in df.columns:
        raise ValueError(f"{label} is missing a DATE column")
    if value_col not in df.columns:
        raise ValueError(f"{label} is missing value column {value_col}")

    if df["DATE"].isna().any():
        raise ValueError(f"{label} has missing or unparseable dates")
    duplicate_count = int(df["DATE"].duplicated().sum())
    if duplicate_count:
        raise ValueError(f"{label} has {duplicate_count} duplicate dates")


def load_raw_series(path: Path, value_col: str, label: str) -> pd.DataFrame:
    df = pd.read_csv(path)
    df["DATE"] = pd.to_datetime(df["DATE"], errors="coerce")
    df[value_col] = pd.to_numeric(df[value_col].replace(".", pd.NA), errors="coerce")
    validate_raw_dates(df, value_col, label)
    return df.sort_values("DATE").reset_index(drop=True)


def aggregate_to_quarter(df: pd.DataFrame, value_col: str, aggregation, label: str) -> pd.Series:
    """Convert raw observations to quarterly values using the configured aggregation."""
    quarterly = df.copy()
    quarterly["quarter"] = quarterly["DATE"].dt.to_period("Q")

    if aggregation is None or pd.isna(aggregation):
        duplicate_quarters = int(quarterly["quarter"].duplicated().sum())
        if duplicate_quarters:
            raise ValueError(f"{label} has {duplicate_quarters} duplicate quarterly observations")
        result = quarterly.set_index("quarter")[value_col]
    elif aggregation == "average":
        result = quarterly.groupby("quarter")[value_col].mean()
    elif aggregation == "sum":
        result = quarterly.groupby("quarter")[value_col].sum(min_count=1)
    elif aggregation in {"last", "end_of_period"}:
        result = quarterly.sort_values("DATE").groupby("quarter")[value_col].last()
    else:
        raise ValueError(f"Unsupported quarterly aggregation for {label}: {aggregation}")

    result.index = result.index.to_timestamp(how="end").normalize()
    result.name = label
    return result.sort_index()


def apply_transformation(series: pd.Series, transformation: str, label: str) -> pd.Series:
    """Apply modelling transformations after quarterly aggregation/alignment."""
    if transformation == "level":
        transformed = series.copy()
    elif transformation == "log_diff":
        non_positive = int((series <= 0).sum())
        if non_positive:
            raise ValueError(f"{label} has {non_positive} non-positive values before log_diff")
        transformed = 100 * np.log(series).diff()
    elif transformation in {"annualised_percent_level", "annualized_percent_level"}:
        transformed = series.copy()
    else:
        raise ValueError(f"Unsupported transformation for {label}: {transformation}")

    transformed.name = label
    return transformed

# %% [markdown]
# ## Load FRED Series

# %%
transformed_series = {}
validation_rows = []

for spec in SERIES_CONFIG:
    name = spec["name"]
    fred_id = spec["fred_id"]
    path = FRED_RAW_DIR / f"{fred_id}.csv"
    raw = load_raw_series(path, fred_id, name)

    quarterly = aggregate_to_quarter(raw, fred_id, spec["quarterly_aggregation"], name)
    transformed = apply_transformation(quarterly, spec["transformation"], name)

    transformed_series[name] = transformed
    validation_rows.append(
        {
            "series": name,
            "raw_start": raw["DATE"].min(),
            "raw_end": raw["DATE"].max(),
            "quarterly_start": quarterly.index.min(),
            "quarterly_end": quarterly.index.max(),
            "raw_missing_values": int(raw[fred_id].isna().sum()),
            "quarterly_missing_values": int(quarterly.isna().sum()),
            "transformation_induced_nans": int(transformed.isna().sum() - quarterly.isna().sum()),
        }
    )

validation = pd.DataFrame(validation_rows)
validation
# Out:
#                              series  raw_start    raw_end quarterly_start  \
# 0                   real_gdp_growth 1947-04-01 2026-01-01      1947-06-30
# 1                 unemployment_rate 1948-01-01 2026-05-01      1948-03-31
# 2             industrial_production 1919-01-01 2026-04-01      1919-03-31
# 3   real_disposable_personal_income 1959-01-01 2026-04-01      1959-03-31
# 4                               cpi 1947-01-01 2026-04-01      1947-03-31
# 5                 house_price_index 1975-01-01 2026-01-01      1975-03-31
# 6                federal_funds_rate 1954-07-01 2026-05-01      1954-09-30
# 7            treasury_10y_2y_spread 1976-06-01 2026-06-05      1976-06-30
# 8                               vix 1990-01-02 2026-06-04      1990-03-31
# 9             corporate_bond_spread 1986-01-02 2026-06-04      1986-03-31
# 10       senior_loan_officer_survey 1990-04-01 2026-04-01      1990-06-30
# 11                  charge_off_rate 1985-01-01 2026-01-01      1985-03-31
#
#    quarterly_end  raw_missing_values  quarterly_missing_values  \
# 0     2026-03-31                   0                         0
# 1     2026-06-30                   1                         0
# 2     2026-06-30                   0                         0
# 3     2026-06-30                   0                         0
# 4     2026-06-30                   1                         0
# 5     2026-03-31                   0                         0
# 6     2026-06-30                   0                         0
# 7     2026-06-30                 549                         0
# 8     2026-06-30                 302                         0
# 9     2026-06-30                 440                         0
# 10    2026-06-30                   0                         0
# 11    2026-03-31                   0                         0
#
#     transformation_induced_nans
# 0                             0
# 1                             0
# 2                             1
# 3                             1
# 4                             1
# 5                             1
# 6                             0
# 7                             0
# 8                             0
# 9                             0
# 10                            0
# 11                            0

# %% [markdown]
# ## Load EBP data and append to dataframe

# %%
EBP_AGGREGATION = "average"
EBP_TRANSFORMATION = "level"

ebp_raw = load_raw_series(EBP_PATH, "EBP", "excess_bond_premium")
ebp_quarterly = aggregate_to_quarter(ebp_raw, "EBP", EBP_AGGREGATION, "excess_bond_premium")
transformed_series["excess_bond_premium"] = apply_transformation(ebp_quarterly, EBP_TRANSFORMATION,"excess_bond_premium",)

# %% [markdown]
# ## Check for missing dates

# %%
panel_with_nans = pd.concat(transformed_series.values(), axis=1, sort=False).sort_index()
panel_with_nans.index.name = "DATE"

# Missing-quarter check
full_quarter_index = pd.date_range(
    panel_with_nans.index.min(),
    panel_with_nans.index.max(),
    freq="QE-DEC",
)
missing_quarter_dates = full_quarter_index.difference(panel_with_nans.index)
if len(missing_quarter_dates):
    raise ValueError(f"Quarterly panel has missing dates: {missing_quarter_dates.tolist()}")

# %% [markdown]
# ## Plot macro-covariates

# %%
n_series = panel_with_nans.shape[1]
n_cols = 3
n_rows = int(np.ceil(n_series / n_cols))

# This overview intentionally uses a wide custom layout rather than TEXT_WIDTH.
fig, axes = plt.subplots(n_rows, n_cols, figsize=(16, 3.2 * n_rows), sharex=False)
axes = axes.ravel()

for ax, column in zip(axes, panel_with_nans.columns):
    series = panel_with_nans[column].dropna()
    ax.plot(series.index, series, linewidth=1.5)
    ax.axhline(0, color="black", linewidth=0.8, alpha=0.25)
    ax.set_title(column.replace("_", " "))
    ax.grid(True, alpha=0.3)

for ax in axes[n_series:]:
    ax.remove()

fig.suptitle("Quarterly macro series", y=0.995, fontsize=16)
fig.tight_layout(rect=[0, 0, 1, 0.98])
fig.savefig('../figures/01_macro_panel/macro_covariates_panel.pdf')
plt.show()

# %% [markdown]
# # Convert to quarterly charge-off rate and create lagged charge-off variable

# %%
macro_panel = panel_with_nans.dropna().reset_index()
macro_panel["c_q"] = macro_panel["charge_off_rate"] / 100 / 4.0
macro_panel["c_q_lag1"] = macro_panel["c_q"].shift(1)

# %%
macro_panel.to_csv(OUTPUT_PATH, index=False)

print(f"Saved {len(macro_panel)} quarterly rows to {OUTPUT_PATH}")
macro_panel.head()
# Out:
# Saved 144 quarterly rows to ../data/processed/macro_panel_quarterly.csv
#         DATE  real_gdp_growth  unemployment_rate  industrial_production  \
# 0 1990-06-30              1.5           5.333333               0.684295
# 1 1990-09-30              0.3           5.700000               0.386851
# 2 1990-12-31             -3.6           6.133333              -1.560018
# 3 1991-03-31             -1.9           6.600000              -1.932577
# 4 1991-06-30              3.2           6.833333               0.526353
#
#    real_disposable_personal_income       cpi  house_price_index  \
# 0                         0.736741  0.984464           0.423064
# 1                         0.014248  1.712502           0.607283
# 2                        -0.804251  1.683668          -0.390403
# 3                         0.306683  0.744790           0.833014
# 4                         0.748178  0.591864           0.660265
#
#    federal_funds_rate  treasury_10y_2y_spread        vix  \
# 0            8.243333                0.103016  18.722063
# 1            8.160000                0.602540  25.195556
# 2            7.743333                0.800161  26.113281
# 3            6.426667                0.987167  22.515833
# 4            5.863333                1.231406  17.147031
#
#    corporate_bond_spread  senior_loan_officer_survey  charge_off_rate  \
# 0               1.638730                        54.4             1.43
# 1               1.706190                        46.7             1.28
# 2               2.197419                        54.2             1.30
# 3               2.186500                        38.6             1.48
# 4               1.795937                        20.0             1.86
#
#    excess_bond_premium       c_q  c_q_lag1
# 0             0.146990  0.003575       NaN
# 1            -0.047302  0.003200  0.003575
# 2             0.266956  0.003250  0.003200
# 3             0.305454  0.003700  0.003250
# 4             0.162705  0.004650  0.003700
